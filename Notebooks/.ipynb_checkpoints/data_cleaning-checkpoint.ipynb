# %%
import pandas as pd
df = pd.read_csv("/Users/souadmouajel/Desktop/Ironhack/lab-sessions/week-8/Ironhack-Final-Project/Data/raw-data/credit_risk_dataset.csv")
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# 1                 0.10                         N                           2
# 2                 0.57                         N                           3
# 3                 0.53                         N                           2
# 4                 0.55                         Y                           4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
   df.duplicated().sum()
# Out:
# np.int64(165)

# %%
import pandas as pd



# Find all duplicate rows
duplicates = df[df.duplicated()]

# Count of duplicates
print(f"Number of duplicate rows: {duplicates.shape[0]}")

# View duplicates
print(duplicates)
# Out:
# Number of duplicate rows: 165
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 15975            VENTURE          B       6000           9.99            0
# 15989          EDUCATION          B       8000          10.36            0
# 15995            MEDICAL          A       4000           5.42            0
# 16025           PERSONAL          A       3000           7.90            1
# 16028          EDUCATION          A      15000           7.88            0
# ...                  ...        ...        ...            ...          ...
# 32010    HOMEIMPROVEMENT          A       2500           5.42            0
# 32047  DEBTCONSOLIDATION          A      20000           7.88            0
# 32172            MEDICAL          B      12000          10.99            0
# 32259            VENTURE          B       1000          10.37            0
# 32279          EDUCATION          C       1950            NaN            1
#
#        loan_percent_income cb_person_default_on_file  \
# 15975                 0.14                         N
# 15989                 0.09                         N
# 15995                 0.08                         N
# 16025                 0.30                         N
# 16028                 0.15                         N
# ...                    ...                       ...
# 32010                 0.06                         N
# 32047                 0.08                         N
# 32172                 0.10                         N
# 32259                 0.03                         N
# 32279                 0.17                         N
#
#        cb_person_cred_hist_length
# 15975                           4
# 15989                           3
# 15995                           4
# 16025                           3
# 16028                           4
# ...                           ...
# 32010                          12
# 32047                          17
# 32172                          12
# 32259                          16
# 32279                          11
#
# [165 rows x 12 columns]

# %%
duplicates.head(40)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# 16038          26          20000              MORTGAGE                5.0
# 16065          22         130000              MORTGAGE                3.0
# 16070          21          27600                  RENT                4.0
# 16079          23          26000                  RENT                1.0
# 16091          23          50000              MORTGAGE                3.0
# 16093          25         128500              MORTGAGE                1.0
# 16111          23          36000                  RENT                1.0
# 16120          23          69996              MORTGAGE                7.0
# 16129          23          58000                 OTHER                0.0
# 16144          24          45000              MORTGAGE                3.0
# 16147          21          65000              MORTGAGE                5.0
# 16172          22          65000              MORTGAGE                4.0
# 16197          22          32400              MORTGAGE                1.0
# 16221          24          48000              MORTGAGE                8.0
# 16238          22          22000                   OWN                1.0
# 16248          22          42000                  RENT                0.0
# 16254          26          50000                  RENT               10.0
# 16255          23          80000              MORTGAGE                1.0
# 16256          22          41000                   OWN                0.0
# 16265          24          98000                   OWN                8.0
# 16271          24          70000                   OWN                8.0
# 16288          24          39000                  RENT                8.0
# 16302          25          48000              MORTGAGE                3.0
# 16311          22          38000              MORTGAGE                6.0
# 16331          25          48000              MORTGAGE                9.0
# 16440          21          26000                  RENT                5.0
# 16448          21          40000              MORTGAGE                5.0
# 16472          21          36000              MORTGAGE                5.0
# 16524          26          59000                  RENT                2.0
# 16552          22          75600              MORTGAGE                3.0
# 16556          24          50000                  RENT                0.0
# 16557          23          20664                  RENT                4.0
# 16559          26          77368                  RENT                1.0
# 16584          23          90000              MORTGAGE                1.0
# 16587          21          26400                  RENT                5.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 15975            VENTURE          B       6000           9.99            0
# 15989          EDUCATION          B       8000          10.36            0
# 15995            MEDICAL          A       4000           5.42            0
# 16025           PERSONAL          A       3000           7.90            1
# 16028          EDUCATION          A      15000           7.88            0
# 16038            MEDICAL          A       4800           5.99            0
# 16065            VENTURE          B      24250          12.18            0
# 16070          EDUCATION          A       7500           6.76            0
# 16079          EDUCATION          B       4000            NaN            0
# 16091          EDUCATION          A      10000           6.03            0
# 16093    HOMEIMPROVEMENT          C      15000          12.53            0
# 16111          EDUCATION          A       7000           7.90            0
# 16120            VENTURE          A       3000           6.39            0
# 16129            VENTURE          B      16000          12.21            0
# 16144            VENTURE          C      15000          13.06            0
# 16147  DEBTCONSOLIDATION          B       2200          12.42            0
# 16172          EDUCATION          A       9000           9.63            0
# 16197  DEBTCONSOLIDATION          A       5500            NaN            0
# 16221            MEDICAL          A      10000           7.49            0
# 16238  DEBTCONSOLIDATION          D       8500          15.05            0
# 16248           PERSONAL          A       3600           7.37            0
# 16254           PERSONAL          B      18950            NaN            1
# 16255          EDUCATION          C      12000          13.48            0
# 16256           PERSONAL          A       1000           6.99            0
# 16265            VENTURE          A      12000           7.49            0
# 16271           PERSONAL          B      24250          12.18            0
# 16288            MEDICAL          D       1500          15.62            0
# 16302  DEBTCONSOLIDATION          B       4800          10.74            0
# 16311  DEBTCONSOLIDATION          A       8500           5.42            0
# 16331          EDUCATION          C       7000          12.09            0
# 16440  DEBTCONSOLIDATION          A       6000           7.49            0
# 16448           PERSONAL          A       5000           6.62            0
# 16472            MEDICAL          B       1000          12.42            0
# 16524           PERSONAL          B       8500          11.83            0
# 16552          EDUCATION          A      10000            NaN            0
# 16556            VENTURE          B       7200          11.71            0
# 16557          EDUCATION          C       4550          13.72            0
# 16559            VENTURE          B      15000          10.00            0
# 16584          EDUCATION          B      12000          12.18            0
# 16587           PERSONAL          C       4750          12.23            0
#
#        loan_percent_income cb_person_default_on_file  \
# 15975                 0.14                         N
# 15989                 0.09                         N
# 15995                 0.08                         N
# 16025                 0.30                         N
# 16028                 0.15                         N
# 16038                 0.24                         N
# 16065                 0.19                         N
# 16070                 0.27                         N
# 16079                 0.15                         N
# 16091                 0.20                         N
# 16093                 0.12                         Y
# 16111                 0.19                         N
# 16120                 0.04                         N
# 16129                 0.28                         N
# 16144                 0.33                         N
# 16147                 0.03                         N
# 16172                 0.14                         N
# 16197                 0.17                         N
# 16221                 0.21                         N
# 16238                 0.39                         N
# 16248                 0.09                         N
# 16254                 0.38                         N
# 16255                 0.15                         Y
# 16256                 0.02                         N
# 16265                 0.12                         N
# 16271                 0.35                         N
# 16288                 0.04                         Y
# 16302                 0.10                         N
# 16311                 0.22                         N
# 16331                 0.15                         Y
# 16440                 0.23                         N
# 16448                 0.13                         N
# 16472                 0.03                         N
# 16524                 0.14                         N
# 16552                 0.13                         N
# 16556                 0.14                         N
# 16557                 0.22                         Y
# 16559                 0.19                         N
# 16584                 0.13                         N
# 16587                 0.18                         N
#
#        cb_person_cred_hist_length
# 15975                           4
# 15989                           3
# 15995                           4
# 16025                           3
# 16028                           4
# 16038                           3
# 16065                           4
# 16070                           4
# 16079                           4
# 16091                           4
# 16093                           3
# 16111                           4
# 16120                           4
# 16129                           4
# 16144                           3
# 16147                           3
# 16172                           3
# 16197                           2
# 16221                           3
# 16238                           4
# 16248                           3
# 16254                           3
# 16255                           4
# 16256                           2
# 16265                           2
# 16271                           2
# 16288                           3
# 16302                           4
# 16311                           2
# 16331                           2
# 16440                           2
# 16448                           2
# 16472                           2
# 16524                           4
# 16552                           4
# 16556                           2
# 16557                           3
# 16559                           3
# 16584                           4
# 16587                           3

# %%
# the Percentage of duplicates are too samll it is less than 0.5% of our dataset.
# Although there is no column for customer_id to be sure wheather they are duplicates or not, the will be dropped.
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32416 non-null  int64
#  1   person_income               32416 non-null  int64
#  2   person_home_ownership       32416 non-null  object
#  3   person_emp_length           31529 non-null  float64
#  4   loan_intent                 32416 non-null  object
#  5   loan_grade                  32416 non-null  object
#  6   loan_amnt                   32416 non-null  int64
#  7   loan_int_rate               29321 non-null  float64
#  8   loan_status                 32416 non-null  int64
#  9   loan_percent_income         32416 non-null  float64
#  10  cb_person_default_on_file   32416 non-null  object
#  11  cb_person_cred_hist_length  32416 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.2+ MB

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
## Make the columns labels clearer:
df.rename(columns={
    'person_emp_length': 'person_employment_length',
    'loan_intent': 'loan_purpose',
    'loan_amnt': 'loan_amount',
    'loan_int_rate': 'loan_interest_rate',
    'loan_percent_income': 'loan_to_income_ratio',
    'cb_person_cred_hist_length': 'cb_credit_history_length'
}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   person_age                 32416 non-null  int64
#  1   person_income              32416 non-null  int64
#  2   person_home_ownership      32416 non-null  object
#  3   person_employment_length   31529 non-null  float64
#  4   loan_purpose               32416 non-null  object
#  5   loan_grade                 32416 non-null  object
#  6   loan_amount                32416 non-null  int64
#  7   loan_interest_rate         29321 non-null  float64
#  8   loan_status                32416 non-null  int64
#  9   loan_to_income_ratio       32416 non-null  float64
#  10  cb_person_default_on_file  32416 non-null  object
#  11  cb_credit_history_length   32416 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.2+ MB

# %%
# Function of Counting missing values, defining where they exist and in which column, its type, their percentage 
def missing_summary(df):
    summary = df.isnull().sum().to_frame(name='missing_count')
    summary['missing_pct'] = (summary['missing_count'] / len(df)) * 100
    summary['missing_pct'] = summary['missing_pct'].apply(lambda x: f"{x:.2f}%")
    summary['dtype'] = df.dtypes
    summary['type'] = summary['dtype'].apply(lambda x: 'numerical' if pd.api.types.is_numeric_dtype(x) else 'categorical')
    summary = summary[summary['missing_count'] > 0]
    return summary.sort_values(by='missing_count', ascending=False)
missing_summary(df)
# Out:
#                           missing_count missing_pct    dtype       type
# loan_interest_rate                 3095       9.55%  float64  numerical
# person_employment_length            887       2.74%  float64  numerical

# %%
## The percentage of missing values in column loan_interest_rat is high and it is a sensitve column. 
## That is why we will anylze it deeper in order to handel them:
## Step 1: Analyze Missingness Pattern
# 1.1 Determine Missingness Mechanism
# Check if missingness is random or systematic
missing_mask = df['loan_interest_rate'].isnull()

# Compare distributions of other variables between missing and non-missing groups
for col in ['loan_grade', 'loan_status', 'person_income', 'loan_amount']:
    print(f"\nComparison for {col}:")
    print(pd.concat([
        df.loc[~missing_mask, col].describe().rename('Not Missing'),
        df.loc[missing_mask, col].describe().rename('Missing')
    ], axis=1))
# Out:
# Comparison for loan_grade:
#        Not Missing Missing
# count        29321    3095
# unique           7       7
# top              A       B
# freq          9713    1050
#
# Comparison for loan_status:
#         Not Missing      Missing
# count  29321.000000  3095.000000
# mean       0.219911     0.207108
# std        0.414193     0.405299
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     0.000000
# 75%        0.000000     0.000000
# max        1.000000     1.000000
#
# Comparison for person_income:
#         Not Missing       Missing
# count  2.932100e+04  3.095000e+03
# mean   6.602976e+04  6.667788e+04
# std    6.192304e+04  6.289264e+04
# min    4.000000e+03  4.888000e+03
# 25%    3.850000e+04  3.865200e+04
# 50%    5.500000e+04  5.600000e+04
# 75%    7.910000e+04  8.000000e+04
# max    6.000000e+06  1.900000e+06
#
# Comparison for loan_amount:
#         Not Missing       Missing
# count  29321.000000   3095.000000
# mean    9587.635142   9652.681745
# std     6316.319639   6383.872307
# min      500.000000    500.000000
# 25%     5000.000000   5000.000000
# 50%     8000.000000   8000.000000
# 75%    12250.000000  12000.000000
# max    35000.000000  35000.000000

# %%
df.loan_grade.unique()
# Out:
# array(['D', 'B', 'C', 'A', 'E', 'F', 'G'], dtype=object)

# %%
## 1.2 Visualize Relationships
import seaborn as sns
import matplotlib.pyplot as plt

# Create a missing indicator plot
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Pattern')
plt.show()

# Check relationship with loan grade
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='loan_grade', y='loan_interest_rate', hue=missing_mask)
plt.title('Interest Rate Distribution by Grade (Missing vs Present)')
plt.show()

# %%
# Calculate missing rate by grade
grade_missing_rates = df.groupby('loan_grade')['loan_interest_rate'].apply(
    lambda x: x.isnull().mean()
).sort_values(ascending=False)

print("Percentage of missing interest rates by grade:")
print(grade_missing_rates)
# Out:
# Percentage of missing interest rates by grade:
# loan_grade
# F    0.112033
# B    0.101088
# C    0.097701
# A    0.092497
# E    0.086189
# D    0.085912
# G    0.078125
# Name: loan_interest_rate, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   person_age                 32416 non-null  int64
#  1   person_income              32416 non-null  int64
#  2   person_home_ownership      32416 non-null  object
#  3   person_employment_length   31529 non-null  float64
#  4   loan_purpose               32416 non-null  object
#  5   loan_grade                 32416 non-null  object
#  6   loan_amount                32416 non-null  int64
#  7   loan_interest_rate         29321 non-null  float64
#  8   loan_status                32416 non-null  int64
#  9   loan_to_income_ratio       32416 non-null  float64
#  10  cb_person_default_on_file  32416 non-null  object
#  11  cb_credit_history_length   32416 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.2+ MB

# %%
df.cb_person_default_on_file.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
# Convert selected columns to lowercase
columns_to_fix = ['person_home_ownership', 'loan_purpose']

for col in columns_to_fix:
    df[col] = df[col].str.lower()

# Print result
print(df[columns_to_fix].head())
# Out:
#   person_home_ownership loan_purpose
# 0                  rent     personal
# 1                   own    education
# 2              mortgage      medical
# 3                  rent      medical
# 4                  rent      medical

# %%
df.loan_purpose.unique()
# Out:
# array(['personal', 'education', 'medical', 'venture', 'homeimprovement',
#        'debtconsolidation'], dtype=object)

# %%
# Mapping of incorrect to correct values
purpose_fixes = {
    'homeimprovement': 'home-improvement',
    'debtconsolidation': 'debt-consolidation'
}
# Clean the 'loan_purpose' column
df['loan_purpose'] = df['loan_purpose'].str.lower().replace(purpose_fixes)

# (Optional) Print unique values to verify
print(df['loan_purpose'].unique())
# Out:
# ['personal' 'education' 'medical' 'venture' 'home-improvement'
#  'debt-consolidation']

# %%
df.person_home_ownership.unique()
# Out:
# array(['rent', 'own', 'mortgage', 'other'], dtype=object)

# %%
df.person_employment_length.describe()
# Out:
# count    31529.00000
# mean         4.79051
# std          4.14549
# min          0.00000
# 25%          2.00000
# 50%          4.00000
# 75%          7.00000
# max        123.00000
# Name: person_employment_length, dtype: float64

# %%
## Replace the mising values in column: person_employment_length with the mode since it has outlires
import pandas as pd


# Calculate the median (excluding NaN)
median_value = df['person_employment_length'].median()

# Fill missing values with median
df['person_employment_length'].fillna(median_value, inplace=True)

# (Optional) Check result
print(df['person_employment_length'].isnull().sum())  # Should be 0
# Out:
# 0
# /var/folders/tn/xjfvdsqn1_d879f1bppyx1xh0000gn/T/ipykernel_2595/1443981783.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['person_employment_length'].fillna(median_value, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   person_age                 32416 non-null  int64
#  1   person_income              32416 non-null  int64
#  2   person_home_ownership      32416 non-null  object
#  3   person_employment_length   32416 non-null  float64
#  4   loan_purpose               32416 non-null  object
#  5   loan_grade                 32416 non-null  object
#  6   loan_amount                32416 non-null  int64
#  7   loan_interest_rate         29321 non-null  float64
#  8   loan_status                32416 non-null  int64
#  9   loan_to_income_ratio       32416 non-null  float64
#  10  cb_person_default_on_file  32416 non-null  object
#  11  cb_credit_history_length   32416 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.2+ MB

# %%
## Check the outliers in the numercial columns:
# Select numeric columns only
numeric_cols = df.select_dtypes(include='number').columns

# Loop through numeric columns and detect outliers
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"{col}: {len(outliers)} outliers")
# Out:
# person_age: 1491 outliers
# person_income: 1478 outliers
# person_employment_length: 852 outliers
# loan_amount: 1679 outliers
# loan_interest_rate: 6 outliers
# loan_status: 7089 outliers
# loan_to_income_ratio: 650 outliers
# cb_credit_history_length: 1139 outliers

# %%
df.loan_status.unique()
# Out:
# array([1, 0])

# %%
# Detecting outliers by boxplott
import matplotlib.pyplot as plt
import seaborn as sns

# Filter only numerical columns with more than 2 unique values (to exclude binary like loan_status)
numeric_cols = [col for col in df.select_dtypes(include='number').columns
                if df[col].nunique() > 2]

# Set up plot size
plt.figure(figsize=(15, len(numeric_cols) * 4))

# Plot each column as a separate subplot
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols), 1, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
# Handeling the outliers:
# Replace extreme values with percentile thresholds (e.g., 1st and 99th):

def cap_outliers(df, col, lower_q=0.01, upper_q=0.99):
    lower = df[col].quantile(lower_q)
    upper = df[col].quantile(upper_q)
    df[col] = df[col].clip(lower, upper)

for col in ['person_age', 'person_income', 'person_employment_length',
            'loan_amount', 'loan_to_income_ratio', 'cb_credit_history_length']:
    cap_outliers(df, col)

# %%
# Plotting outliers after capping them. Binary values column will not be included
numeric_cols = [col for col in df.select_dtypes(include='number').columns
                if df[col].nunique() > 2]

# Set up plot size
plt.figure(figsize=(15, len(numeric_cols) * 4))

# Plot each column as a separate subplot
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(len(numeric_cols), 1, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)

plt.tight_layout()
plt.show()

# %%
# There are two columns still suffer of a lote of outliers after capping: person_income and loan_amount. 
# Log trasnformation will be implemented on them
df['person_income_log'] = np.log1p(df['person_income'])

# %%
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(df['person_income_log'], kde=True, bins=30)
plt.title('Histogram of Log-Transformed Person Income')
plt.xlabel('Log(Person Income)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['person_income_log'])
plt.title('Boxplot of Log-Transformed Person Income')
plt.xlabel('Log(Person Income)')
plt.show()

# %%
df['loan_amount_log'] = np.log1p(df['loan_amount'])
plt.figure(figsize=(8, 5))
sns.histplot(df['loan_amount_log'], kde=True, bins=30)
plt.title('Histogram of Log-Transformed Loan Amount')
plt.xlabel('Log(Loan Amount)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 2))
sns.boxplot(x=df['loan_amount_log'])
plt.title('Boxplot of Log-Transformed Loan Amount')
plt.xlabel('Log(Loan Amount)')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['loan_amount'], kde=True, bins=30)
plt.title('Histogram of Log-Transformed Loan Amount')
plt.xlabel('Log(Loan Amount)')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 5))

# Before
plt.subplot(1, 2, 1)
sns.histplot(df['loan_amount'], kde=True, bins=30)
plt.title('Original Loan Amount')

# After
plt.subplot(1, 2, 2)
sns.histplot(df['loan_amount_log'], kde=True, bins=30)
plt.title('Log-Transformed Loan Amount')

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   person_age                 32416 non-null  int64
#  1   person_income              32416 non-null  int64
#  2   person_home_ownership      32416 non-null  object
#  3   person_employment_length   32416 non-null  float64
#  4   loan_purpose               32416 non-null  object
#  5   loan_grade                 32416 non-null  object
#  6   loan_amount                32416 non-null  int64
#  7   loan_interest_rate         29321 non-null  float64
#  8   loan_status                32416 non-null  int64
#  9   loan_to_income_ratio       32416 non-null  float64
#  10  cb_person_default_on_file  32416 non-null  object
#  11  cb_credit_history_length   32416 non-null  int64
#  12  person_income_log          32416 non-null  float64
#  13  loan_amount_log            32416 non-null  float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 3.7+ MB

# %%
df.loan_grade.value_counts()
# Out:
# loan_grade
# A    10703
# B    10387
# C     6438
# D     3620
# E      963
# F      241
# G       64
# Name: count, dtype: int64

# %%
## Regard the categorical columns. All of them looks fine except of loan_grade where there are very small categories.
## The small categories E, F, G will be groubed together in one new category: E_or_lower:
df['loan_grade'] = df['loan_grade'].replace({'E': 'E_or_lower', 'F': 'E_or_lower', 'G': 'E_or_lower'})
df.loan_grade.value_counts()
# Out:
# loan_grade
# A             10703
# B             10387
# C              6438
# D              3620
# E_or_lower     1268
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   person_age                 32416 non-null  int64
#  1   person_income              32416 non-null  int64
#  2   person_home_ownership      32416 non-null  object
#  3   person_employment_length   32416 non-null  float64
#  4   loan_purpose               32416 non-null  object
#  5   loan_grade                 32416 non-null  object
#  6   loan_amount                32416 non-null  int64
#  7   loan_interest_rate         29321 non-null  float64
#  8   loan_status                32416 non-null  int64
#  9   loan_to_income_ratio       32416 non-null  float64
#  10  cb_person_default_on_file  32416 non-null  object
#  11  cb_credit_history_length   32416 non-null  int64
#  12  person_income_log          32416 non-null  float64
#  13  loan_amount_log            32416 non-null  float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 3.7+ MB

# %%
# Data type valedation and change
# Cast object columns to category
categorical_cols = [
    'person_home_ownership', 
    'loan_purpose', 
    'loan_grade', 
    'cb_person_default_on_file'
]
df[categorical_cols] = df[categorical_cols].astype('category')

# convert binary column to bool or category
df['loan_status'] = df['loan_status'].astype('bool')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32416 entries, 0 to 32580
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   person_age                 32416 non-null  int64
#  1   person_income              32416 non-null  int64
#  2   person_home_ownership      32416 non-null  category
#  3   person_employment_length   32416 non-null  float64
#  4   loan_purpose               32416 non-null  category
#  5   loan_grade                 32416 non-null  category
#  6   loan_amount                32416 non-null  int64
#  7   loan_interest_rate         29321 non-null  float64
#  8   loan_status                32416 non-null  bool
#  9   loan_to_income_ratio       32416 non-null  float64
#  10  cb_person_default_on_file  32416 non-null  category
#  11  cb_credit_history_length   32416 non-null  int64
#  12  person_income_log          32416 non-null  float64
#  13  loan_amount_log            32416 non-null  float64
# dtypes: bool(1), category(4), float64(5), int64(4)
# memory usage: 2.6 MB
